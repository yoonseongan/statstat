# %%
import pandas as pd

import requests

# %%
json_URL = 'https://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=NzE3NTVkNWM5OTU4NjM4NjcwNDBiYTM0MzQwOTFlZjQ=&format=json&jsonVD=Y&userStatsId=ysahn34/101/DT_1J20112/2/1/20231203004217&prdSe=Q&startPrdDe=201701&endPrdDe=202303'
a = 'C:/Users/안윤성/Desktop/ysahn/statstat/a.csv'

response = requests.get(json_URL)

# %%
response
# Out:
# <Response [200]>

# %%
test_data = response.json()

# %%
test_data
# Out:
# [{'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201701',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '93.556',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201702',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '90.453',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201703',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '93.699',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201704',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '90.122',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201801',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '94.222',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201802',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '92.302',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201803',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '98.27',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201804',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '96.516',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201901',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '94.443',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201902',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '93.413',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201903',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '92.929',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201904',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '94.146',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202001',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '95.64',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202002',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '96.72',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202003',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '103.48',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202004',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '104.16',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202101',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '108.36',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202102',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '107.66',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202103',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '109.29',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202104',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '109.59',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202201',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '111.31',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202202',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '111.56',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202203',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '116.71',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202204',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '111.7',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202301',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '113.24',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202302',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '111.86',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202303',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '119.06',
#   'PRD_SE': 'Q',
#   'C2': 'A',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '농축수산물',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Agricultural ＆ marine products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201701',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '99.16',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201702',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '98.977',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201703',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '98.859',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201704',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '99.514',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201801',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '99.877',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201802',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '100.431',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201803',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '100.614',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201804',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '100.617',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201901',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '99.177',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201902',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '100.473',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201903',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '100.44',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201904',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '100.807',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202001',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '101.08',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202002',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '99.3',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202003',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '99.86',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202004',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '99.76',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202101',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '100.7',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202102',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '101.53',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202103',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '102.63',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202104',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '104.31',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202201',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '106.14',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202202',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '110.12',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202203',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '110.36',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202204',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '110.68',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202301',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '111.09',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202302',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '111.6',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202303',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '112.53',
#   'PRD_SE': 'Q',
#   'C2': 'B',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '공업제품',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Industrial products'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201701',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '102.43',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201702',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '103.725',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201703',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '103.809',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201704',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '101.557',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201801',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '100.53',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201802',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '100.576',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201803',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '96.572',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201804',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '101.886',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201901',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '101.855',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201902',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '101.851',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201903',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '98.426',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201904',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '103.414',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202001',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '103.33',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202002',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '103.1',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202003',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '94.25',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202004',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '99.31',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202101',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '98.2',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202102',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '98.2',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202103',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '94.53',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202104',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '100.68',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202201',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '101.08',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202202',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '106.72',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202203',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '109',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202204',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '123.97',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202301',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '129.76',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202302',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '132.65',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202303',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '131.23',
#   'PRD_SE': 'Q',
#   'C2': 'C',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '전기 · 가스 · 수도',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Electricity and Gas and Water'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201701',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '94.001',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201702',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '94.445',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201703',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '95.056',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201704',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '95.02',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201801',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '96.068',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201802',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '97.042',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201803',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '97.479',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201804',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '97.488',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201901',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '98.308',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201902',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '98.686',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201903',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '99.171',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '201904',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '99.09',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202001',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '99.54',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202002',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '99.72',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202003',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '100.27',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202004',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '100.46',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202101',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '101.39',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202102',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '102.22',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202103',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '103.02',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202104',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '103.55',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202201',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '105.66',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202202',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '107.46',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202203',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '109.34',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202204',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '109.99',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202301',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '111.78',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202302',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '113.46',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'},
#  {'TBL_NM': '품목별 소비자물가지수(품목성질별: 2020＝100)',
#   'PRD_DE': '202303',
#   'TBL_ID': 'DT_1J20112',
#   'ITM_NM': '소비자물가지수',
#   'ITM_NM_ENG': 'CPI',
#   'ITM_ID': 'T',
#   'UNIT_NM': '2020＝100',
#   'ORG_ID': '101',
#   'UNIT_NM_ENG': '2020＝100',
#   'C1_OBJ_NM': '시도별',
#   'C1_OBJ_NM_ENG': 'by City',
#   'C2_OBJ_NM': '품목별',
#   'C2_OBJ_NM_ENG': 'by Item',
#   'DT': '114.12',
#   'PRD_SE': 'Q',
#   'C2': 'F',
#   'C1': 'T10',
#   'C1_NM': '전국',
#   'C2_NM': '개인서비스',
#   'C1_NM_ENG': 'whole country',
#   'C2_NM_ENG': 'Personal services'}]

# %%
df = pd.json_normalize(test_data)

# %%
df
# Out:
#                            TBL_NM  PRD_DE      TBL_ID   ITM_NM ITM_NM_ENG  \
# 0    품목별 소비자물가지수(품목성질별: 2020＝100)  201701  DT_1J20112  소비자물가지수        CPI
# 1    품목별 소비자물가지수(품목성질별: 2020＝100)  201702  DT_1J20112  소비자물가지수        CPI
# 2    품목별 소비자물가지수(품목성질별: 2020＝100)  201703  DT_1J20112  소비자물가지수        CPI
# 3    품목별 소비자물가지수(품목성질별: 2020＝100)  201704  DT_1J20112  소비자물가지수        CPI
# 4    품목별 소비자물가지수(품목성질별: 2020＝100)  201801  DT_1J20112  소비자물가지수        CPI
# ..                            ...     ...         ...      ...        ...
# 103  품목별 소비자물가지수(품목성질별: 2020＝100)  202203  DT_1J20112  소비자물가지수        CPI
# 104  품목별 소비자물가지수(품목성질별: 2020＝100)  202204  DT_1J20112  소비자물가지수        CPI
# 105  품목별 소비자물가지수(품목성질별: 2020＝100)  202301  DT_1J20112  소비자물가지수        CPI
# 106  품목별 소비자물가지수(품목성질별: 2020＝100)  202302  DT_1J20112  소비자물가지수        CPI
# 107  품목별 소비자물가지수(품목성질별: 2020＝100)  202303  DT_1J20112  소비자물가지수        CPI
#
#     ITM_ID   UNIT_NM ORG_ID UNIT_NM_ENG C1_OBJ_NM  ... C2_OBJ_NM  \
# 0        T  2020＝100    101    2020＝100       시도별  ...       품목별
# 1        T  2020＝100    101    2020＝100       시도별  ...       품목별
# 2        T  2020＝100    101    2020＝100       시도별  ...       품목별
# 3        T  2020＝100    101    2020＝100       시도별  ...       품목별
# 4        T  2020＝100    101    2020＝100       시도별  ...       품목별
# ..     ...       ...    ...         ...       ...  ...       ...
# 103      T  2020＝100    101    2020＝100       시도별  ...       품목별
# 104      T  2020＝100    101    2020＝100       시도별  ...       품목별
# 105      T  2020＝100    101    2020＝100       시도별  ...       품목별
# 106      T  2020＝100    101    2020＝100       시도별  ...       품목별
# 107      T  2020＝100    101    2020＝100       시도별  ...       품목별
#
#     C2_OBJ_NM_ENG      DT PRD_SE C2   C1 C1_NM  C2_NM      C1_NM_ENG  \
# 0         by Item  93.556      Q  A  T10    전국  농축수산물  whole country
# 1         by Item  90.453      Q  A  T10    전국  농축수산물  whole country
# 2         by Item  93.699      Q  A  T10    전국  농축수산물  whole country
# 3         by Item  90.122      Q  A  T10    전국  농축수산물  whole country
# 4         by Item  94.222      Q  A  T10    전국  농축수산물  whole country
# ..            ...     ...    ... ..  ...   ...    ...            ...
# 103       by Item  109.34      Q  F  T10    전국  개인서비스  whole country
# 104       by Item  109.99      Q  F  T10    전국  개인서비스  whole country
# 105       by Item  111.78      Q  F  T10    전국  개인서비스  whole country
# 106       by Item  113.46      Q  F  T10    전국  개인서비스  whole country
# 107       by Item  114.12      Q  F  T10    전국  개인서비스  whole country
#
#                           C2_NM_ENG
# 0    Agricultural ＆ marine products
# 1    Agricultural ＆ marine products
# 2    Agricultural ＆ marine products
# 3    Agricultural ＆ marine products
# 4    Agricultural ＆ marine products
# ..                              ...
# 103               Personal services
# 104               Personal services
# 105               Personal services
# 106               Personal services
# 107               Personal services
#
# [108 rows x 21 columns]

# %%
df.to_csv('test1.csv', encoding = 'cp949')

# %%
df=df[['PRD_DE','DT','C2_NM_ENG']]

# %%
df.head()
# Out:
#    PRD_DE      DT                       C2_NM_ENG
# 0  201701  93.556  Agricultural ＆ marine products
# 1  201702  90.453  Agricultural ＆ marine products
# 2  201703  93.699  Agricultural ＆ marine products
# 3  201704  90.122  Agricultural ＆ marine products
# 4  201801  94.222  Agricultural ＆ marine products

# %%
df=df.rename(columns={'PRD_DE':'기간(분기)','DT':'물가지수','C2_NM_ENG':'분야(영어)'})

# %%
df.to_csv('test1.csv', encoding = 'cp949') # csv파일 다시 저장

# %%
df.head()
# Out:
#    기간(분기)    물가지수                          분야(영어)
# 0  201701  93.556  Agricultural ＆ marine products
# 1  201702  90.453  Agricultural ＆ marine products
# 2  201703  93.699  Agricultural ＆ marine products
# 3  201704  90.122  Agricultural ＆ marine products
# 4  201801  94.222  Agricultural ＆ marine products

# %%
df.set_index('기간(분기)',inplace=True)

# %%
df.head()
# Out:
#           물가지수                          분야(영어)
# 기간(분기)
# 201701  93.556  Agricultural ＆ marine products
# 201702  90.453  Agricultural ＆ marine products
# 201703  93.699  Agricultural ＆ marine products
# 201704  90.122  Agricultural ＆ marine products
# 201801  94.222  Agricultural ＆ marine products

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108 entries, 201701 to 202303
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   물가지수    108 non-null    object
#  1   분야(영어)  108 non-null    object
# dtypes: object(2)
# memory usage: 2.5+ KB
# None

# %%
# '분야(영어)' 열의 고유한 값 찾기
a = df['분야(영어)'].unique()

print(a)
# Out:
# ['Agricultural ＆ marine products' 'Industrial products'
#  'Electricity and Gas and Water' 'Personal services']

# %%
# '물가지수' 열을 숫자로 변환
df['물가지수'] = pd.to_numeric(df['물가지수'], errors='coerce')

# 변환 후 데이터프레임 정보 확인
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108 entries, 201701 to 202303
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   물가지수    108 non-null    float64
#  1   분야(영어)  108 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 2.5+ KB
# None

# %%
df.groupby('분야(영어)').mean()
# Out:
#                                       물가지수
# 분야(영어)
# Agricultural ＆ marine products  102.015222
# Electricity and Gas and Water   105.283000
# Industrial products             102.986519
# Personal services               101.623481

# %%
df.groupby('분야(영어)').count()
# Out:
#                                 물가지수
# 분야(영어)
# Agricultural ＆ marine products    27
# Electricity and Gas and Water     27
# Industrial products               27
# Personal services                 27

# %%
df.groupby('분야(영어)').max()
# Out:
#                                   물가지수
# 분야(영어)
# Agricultural ＆ marine products  119.06
# Electricity and Gas and Water   132.65
# Industrial products             112.53
# Personal services               114.12

# %%
df.groupby('분야(영어)').describe()
# Out:
#                                 물가지수                                          \
#                                count        mean        std     min      25%
# 분야(영어)
# Agricultural ＆ marine products  27.0  102.015222   9.092551  90.122  93.9225
# Electricity and Gas and Water   27.0  105.283000  10.813171  94.250  99.9200
# Industrial products             27.0  102.986519   4.687489  98.859  99.8100
# Personal services               27.0  101.623481   5.919660  94.001  97.4835
#
#
#                                     50%      75%     max
# 분야(영어)
# Agricultural ＆ marine products   98.270  110.450  119.06
# Electricity and Gas and Water   101.855  103.767  132.65
# Industrial products             100.617  105.225  112.53
# Personal services                99.720  104.605  114.12

# %%
piv_table_dict = {}

# %%
a=df[['물가지수']]

# %%
print(a)
# Out:
#            물가지수
# 기간(분기)
# 201701   93.556
# 201702   90.453
# 201703   93.699
# 201704   90.122
# 201801   94.222
# ...         ...
# 202203  109.340
# 202204  109.990
# 202301  111.780
# 202302  113.460
# 202303  114.120
#
# [108 rows x 1 columns]

# %%
b=a[['물가지수']]

# %%
print(b)
# Out:
#            물가지수
# 기간(분기)
# 201701   93.556
# 201702   90.453
# 201703   93.699
# 201704   90.122
# 201801   94.222
# ...         ...
# 202203  109.340
# 202204  109.990
# 202301  111.780
# 202302  113.460
# 202303  114.120
#
# [108 rows x 1 columns]

# %%
ndf=df.pivot(columns='분야(영어)', values='물가지수')

# %%
ndf
# Out:
# 분야(영어)  Agricultural ＆ marine products  Electricity and Gas and Water  \
# 기간(분기)
# 201701                          93.556                        102.430
# 201702                          90.453                        103.725
# 201703                          93.699                        103.809
# 201704                          90.122                        101.557
# 201801                          94.222                        100.530
# 201802                          92.302                        100.576
# 201803                          98.270                         96.572
# 201804                          96.516                        101.886
# 201901                          94.443                        101.855
# 201902                          93.413                        101.851
# 201903                          92.929                         98.426
# 201904                          94.146                        103.414
# 202001                          95.640                        103.330
# 202002                          96.720                        103.100
# 202003                         103.480                         94.250
# 202004                         104.160                         99.310
# 202101                         108.360                         98.200
# 202102                         107.660                         98.200
# 202103                         109.290                         94.530
# 202104                         109.590                        100.680
# 202201                         111.310                        101.080
# 202202                         111.560                        106.720
# 202203                         116.710                        109.000
# 202204                         111.700                        123.970
# 202301                         113.240                        129.760
# 202302                         111.860                        132.650
# 202303                         119.060                        131.230
#
# 분야(영어)  Industrial products  Personal services
# 기간(분기)
# 201701               99.160             94.001
# 201702               98.977             94.445
# 201703               98.859             95.056
# 201704               99.514             95.020
# 201801               99.877             96.068
# 201802              100.431             97.042
# 201803              100.614             97.479
# 201804              100.617             97.488
# 201901               99.177             98.308
# 201902              100.473             98.686
# 201903              100.440             99.171
# 201904              100.807             99.090
# 202001              101.080             99.540
# 202002               99.300             99.720
# 202003               99.860            100.270
# 202004               99.760            100.460
# 202101              100.700            101.390
# 202102              101.530            102.220
# 202103              102.630            103.020
# 202104              104.310            103.550
# 202201              106.140            105.660
# 202202              110.120            107.460
# 202203              110.360            109.340
# 202204              110.680            109.990
# 202301              111.090            111.780
# 202302              111.600            113.460
# 202303              112.530            114.120

# %%
agricultural_data = ndf['Agricultural ＆ marine products'].mean()
print('mean : ',agricultural_data)
agricultural_data = ndf['Agricultural ＆ marine products'].max()
print('max : ',agricultural_data)
agricultural_data = ndf['Agricultural ＆ marine products'].count()
print('count : ',agricultural_data)
# Out:
# mean :  102.01522222222222
# max :  119.06
# count :  27

# %%
Industrial_data = ndf['Industrial products'].mean()
print('mean : ', Industrial_data)
Industrial_data = ndf['Industrial products'].max()
print('max : ', Industrial_data)
Industrial_data = ndf['Industrial products'].count()
print('count : ', Industrial_data)
# Out:
# mean :  102.98651851851854
# max :  112.53
# count :  27

# %%
Electricity_data = ndf['Electricity and Gas and Water'].mean()
print('mean : ', Electricity_data)
Electricity_data = ndf['Electricity and Gas and Water'].max()
print('max : ', Electricity_data)
Electricity_data = ndf['Electricity and Gas and Water'].count()
print('count : ', Electricity_data)
# Out:
# mean :  105.28300000000002
# max :  132.65
# count :  27

# %%
services_data = ndf['Personal services'].mean()
print('mean : ', services_data)
services_data = ndf['Personal services'].max()
print('max : ', services_data)
services_data = ndf['Personal services'].count()
print('count : ', services_data)
# Out:
# mean :  101.62348148148149
# max :  114.12
# count :  27

# %%
print(ndf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, 201701 to 202303
# Data columns (total 4 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Agricultural ＆ marine products  27 non-null     float64
#  1   Electricity and Gas and Water   27 non-null     float64
#  2   Industrial products             27 non-null     float64
#  3   Personal services               27 non-null     float64
# dtypes: float64(4)
# memory usage: 1.1+ KB
# None

# %%
print(ndf.describe())
# Out:
# 분야(영어)  Agricultural ＆ marine products  Electricity and Gas and Water  \
# count                        27.000000                      27.000000
# mean                        102.015222                     105.283000
# std                           9.092551                      10.813171
# min                          90.122000                      94.250000
# 25%                          93.922500                      99.920000
# 50%                          98.270000                     101.855000
# 75%                         110.450000                     103.767000
# max                         119.060000                     132.650000
#
# 분야(영어)  Industrial products  Personal services
# count             27.000000          27.000000
# mean             102.986519         101.623481
# std                4.687489           5.919660
# min               98.859000          94.001000
# 25%               99.810000          97.483500
# 50%              100.617000          99.720000
# 75%              105.225000         104.605000
# max              112.530000         114.120000

# %%
columns_to_convert = ['Agricultural ＆ marine products', 'Electricity and Gas and Water', 'Industrial products', 'Personal services']

# %%
ndf[columns_to_convert] = ndf[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
print(ndf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, 201701 to 202303
# Data columns (total 4 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Agricultural ＆ marine products  27 non-null     float64
#  1   Electricity and Gas and Water   27 non-null     float64
#  2   Industrial products             27 non-null     float64
#  3   Personal services               27 non-null     float64
# dtypes: float64(4)
# memory usage: 1.1+ KB
# None

# %%
# 'Personal services' 열을 기준으로 그룹화하고 평균을 계산
a = ndf.groupby(by='Personal services').mean()

# 결과 출력
print(a)
# Out:
# 분야(영어)             Agricultural ＆ marine products  \
# Personal services
# 94.001                                     93.556
# 94.445                                     90.453
# 95.020                                     90.122
# 95.056                                     93.699
# 96.068                                     94.222
# 97.042                                     92.302
# 97.479                                     98.270
# 97.488                                     96.516
# 98.308                                     94.443
# 98.686                                     93.413
# 99.090                                     94.146
# 99.171                                     92.929
# 99.540                                     95.640
# 99.720                                     96.720
# 100.270                                   103.480
# 100.460                                   104.160
# 101.390                                   108.360
# 102.220                                   107.660
# 103.020                                   109.290
# 103.550                                   109.590
# 105.660                                   111.310
# 107.460                                   111.560
# 109.340                                   116.710
# 109.990                                   111.700
# 111.780                                   113.240
# 113.460                                   111.860
# 114.120                                   119.060
#
# 분야(영어)             Electricity and Gas and Water  Industrial products
# Personal services
# 94.001                                   102.430               99.160
# 94.445                                   103.725               98.977
# 95.020                                   101.557               99.514
# 95.056                                   103.809               98.859
# 96.068                                   100.530               99.877
# 97.042                                   100.576              100.431
# 97.479                                    96.572              100.614
# 97.488                                   101.886              100.617
# 98.308                                   101.855               99.177
# 98.686                                   101.851              100.473
# 99.090                                   103.414              100.807
# 99.171                                    98.426              100.440
# 99.540                                   103.330              101.080
# 99.720                                   103.100               99.300
# 100.270                                   94.250               99.860
# 100.460                                   99.310               99.760
# 101.390                                   98.200              100.700
# 102.220                                   98.200              101.530
# 103.020                                   94.530              102.630
# 103.550                                  100.680              104.310
# 105.660                                  101.080              106.140
# 107.460                                  106.720              110.120
# 109.340                                  109.000              110.360
# 109.990                                  123.970              110.680
# 111.780                                  129.760              111.090
# 113.460                                  132.650              111.600
# 114.120                                  131.230              112.530

# %%
print(ndf.describe())
# Out:
# 분야(영어)  Agricultural ＆ marine products  Electricity and Gas and Water  \
# count                        27.000000                      27.000000
# mean                        102.015222                     105.283000
# std                           9.092551                      10.813171
# min                          90.122000                      94.250000
# 25%                          93.922500                      99.920000
# 50%                          98.270000                     101.855000
# 75%                         110.450000                     103.767000
# max                         119.060000                     132.650000
#
# 분야(영어)  Industrial products  Personal services
# count             27.000000          27.000000
# mean             102.986519         101.623481
# std                4.687489           5.919660
# min               98.859000          94.001000
# 25%               99.810000          97.483500
# 50%              100.617000          99.720000
# 75%              105.225000         104.605000
# max              112.530000         114.120000

# %%
ndf.plot()
# Out:
# <Axes: xlabel='기간(분기)'>
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 50556 (\N{HANGUL SYLLABLE YA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 65286 (\N{FULLWIDTH AMPERSAND}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50556 (\N{HANGUL SYLLABLE YA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 65286 (\N{FULLWIDTH AMPERSAND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = ndf[['Agricultural ＆ marine products','Electricity and Gas and Water','Industrial products']]
y=ndf['Personal services']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
print('traindata: ',x_train.shape)
print('testdata : ',x_test.shape)
# Out:
# traindata:  (18, 3)
# testdata :  (9, 3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
r_square = lr.score(x_test,y_test)
print(r_square)
# Out:
# 0.9566727500121982

# %%
print('x 변수의 계수 a :', lr.coef_)
# Out:
# x 변수의 계수 a : [0.31190431 0.14312781 0.40354371]

# %%
print('상수항 b', lr.intercept_)
# Out:
# 상수항 b 13.296203302872783

# %%
y_hat = lr.predict(x_test)

# %%
plt.figure(figsize=(10,5))
ax1=sns.kdeplot(y_test,label="y_test")
ax2= sns.kdeplot(y_hat, label="y_hat",ax=ax1)
plt.legend()
plt.show() #전체적인 회귀

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 독립 변수 열 선택
independent_variable_columns = ['Agricultural ＆ marine products', 'Electricity and Gas and Water', 'Industrial products']

# 종속 변수 열 선택
dependent_variable_column = 'Personal services'  

# 데이터프레임에서 필요한 열만 추출
data = ndf[independent_variable_columns + [dependent_variable_column]]

# seaborn을 사용하여 부분 회귀 플롯 그리기
sns.pairplot(data)
plt.show()
# Out:
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:123: UserWarning: Glyph 65286 (\N{FULLWIDTH AMPERSAND}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\안윤성\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 65286 (\N{FULLWIDTH AMPERSAND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
independent_variable_columns = ['Agricultural ＆ marine products', 'Electricity and Gas and Water', 'Industrial products']

# 종속 변수 열 선택
dependent_variable_column = 'Personal services'

# 데이터프레임에서 필요한 열만 추출
data = ndf[independent_variable_columns + [dependent_variable_column]]

# 독립 변수와 종속 변수를 분리
X = data[independent_variable_columns]
y = data[dependent_variable_column]

# 회귀 모델 초기화 및 학습
model = LinearRegression()
model.fit(X, y)

# 각 독립 변수의 계수 확인
coefficients = model.coef_

# 결과 출력
for i in range(len(independent_variable_columns)):
    print(f"{independent_variable_columns[i]}의 계수: {coefficients[i]}")
# Out:
# Agricultural ＆ marine products의 계수: 0.31862974426086327
# Electricity and Gas and Water의 계수: 0.11860096775422774
# Industrial products의 계수: 0.45752069981784316

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm

# 독립 변수 열 선택
independent_variable_columns = ['Agricultural ＆ marine products', 'Electricity and Gas and Water', 'Industrial products']

# 데이터프레임에서 필요한 열만 추출
data = ndf[independent_variable_columns]

# 상관 행렬 확인
correlation_matrix = data.corr()
print("상관 행렬:")
print(correlation_matrix)

# VIF 확인
X = sm.add_constant(data)
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print("\nVIF:")
print(vif_data)
# Out:
# 상관 행렬:
# 분야(영어)                          Agricultural ＆ marine products  \
# 분야(영어)
# Agricultural ＆ marine products                        1.000000
# Electricity and Gas and Water                         0.531622
# Industrial products                                   0.847938
#
# 분야(영어)                          Electricity and Gas and Water  \
# 분야(영어)
# Agricultural ＆ marine products                       0.531622
# Electricity and Gas and Water                        1.000000
# Industrial products                                  0.815413
#
# 분야(영어)                          Industrial products
# 분야(영어)
# Agricultural ＆ marine products             0.847938
# Electricity and Gas and Water              0.815413
# Industrial products                        1.000000
#
# VIF:
#                          Variable          VIF
# 0                           const  1358.170566
# 1  Agricultural ＆ marine products     4.882843
# 2   Electricity and Gas and Water     4.094535
# 3             Industrial products    10.453097

# %%
# 'Industrial products' 변수를 제외한 독립 변수 열 선택
independent_variable_columns_updated = ['Agricultural ＆ marine products', 'Electricity and Gas and Water']

# 데이터프레임에서 필요한 열만 추출
data_updated = ndf[independent_variable_columns_updated + ['Personal services']]

# 독립 변수와 종속 변수를 분리
X_updated = sm.add_constant(data_updated[independent_variable_columns_updated])
y_updated = data_updated['Personal services']

# 새로운 모델 초기화 및 학습
model_updated = sm.OLS(y_updated, X_updated).fit()

# 새로운 모델의 요약 정보 출력
print(model_updated.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Personal services   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.942
# Method:                 Least Squares   F-statistic:                     212.6
# Date:                Tue, 05 Dec 2023   Prob (F-statistic):           5.40e-16
# Time:                        01:09:05   Log-Likelihood:                -46.266
# No. Observations:                  27   AIC:                             98.53
# Df Residuals:                      24   BIC:                             102.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             32.1170      3.382      9.495      0.000      25.136      39.098
# Agricultural ＆ marine products     0.4549      0.036     12.544      0.000       0.380       0.530
# Electricity and Gas and Water      0.2194      0.030      7.195      0.000       0.156       0.282
# ==============================================================================
# Omnibus:                        0.622   Durbin-Watson:                   0.797
# Prob(Omnibus):                  0.733   Jarque-Bera (JB):                0.092
# Skew:                          -0.121   Prob(JB):                        0.955
# Kurtosis:                       3.153   Cond. No.                     1.82e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.82e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# 회귀 모델 요약:
#
# 결정계수(R-squared): 0.947
# 수정된 결정계수(Adj. R-squared): 0.942
# F 통계량: 212.6
# F 통계량의 p-value: 5.40e-16 (매우 작음)
# 계수 (회귀 계수):
#
# 'Agricultural ＆ marine products'의 회귀 계수: 0.4549
# 'Electricity and Gas and Water'의 회귀 계수: 0.2194
# 통계적 유의성 (P-value):
#
# 'Agricultural ＆ marine products'의 P-value: 0.000 (통계적으로 유의함)
# 'Electricity and Gas and Water'의 P-value: 0.000 (통계적으로 유의함)
# 해석:
#
# 새로운 모델은 전체 데이터의 94.7%를 설명하는 것으로 나타났습니다 (R-squared).
# 'Agricultural ＆ marine products'와 'Electricity and Gas and Water' 변수들은 종속 변수인 'Personal services'에 통계적으로 유의미한 영향을 미치는 것으로 나타났습니다.
# 주의 사항:
#
# 모델의 조건 수(condition number)가 크게 나타났습니다. 이는 강한 다중 공선성 또는 다른 수치적 문제가 있을 수 있다는 신호일 수 있습니다.
# 추가 조치:
#
# 다중 공선성이 여전히 문제가 될 수 있으므로, 조금 더 변수를 조정하거나 추가적인 다중 공선성 진단을 수행하는 것이 좋습니다.
# 변수 선택이나 변수 변환 기법을 사용하여 모델을 개선하고, 필요한 경우에는 다른 변수를 추가하거나 제거하여 모델을 더욱 믿을 수 있게 만들어 볼 수 있습니다.

# %%
# 'Industrial products' 변수를 제외한 독립 변수 열 선택
independent_variable_columns_updated = ['Agricultural ＆ marine products', 'Electricity and Gas and Water']

# 데이터프레임에서 필요한 열만 추출
data_updated = ndf[independent_variable_columns_updated + ['Personal services']]

# 독립 변수와 종속 변수를 분리
X_updated = sm.add_constant(data_updated[independent_variable_columns_updated])
y_updated = data_updated['Personal services']

# 새로운 모델 초기화 및 학습
model_updated = sm.OLS(y_updated, X_updated).fit()

# 새로운 모델의 요약 정보 출력
print(model_updated.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Personal services   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.942
# Method:                 Least Squares   F-statistic:                     212.6
# Date:                Tue, 05 Dec 2023   Prob (F-statistic):           5.40e-16
# Time:                        01:09:05   Log-Likelihood:                -46.266
# No. Observations:                  27   AIC:                             98.53
# Df Residuals:                      24   BIC:                             102.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             32.1170      3.382      9.495      0.000      25.136      39.098
# Agricultural ＆ marine products     0.4549      0.036     12.544      0.000       0.380       0.530
# Electricity and Gas and Water      0.2194      0.030      7.195      0.000       0.156       0.282
# ==============================================================================
# Omnibus:                        0.622   Durbin-Watson:                   0.797
# Prob(Omnibus):                  0.733   Jarque-Bera (JB):                0.092
# Skew:                          -0.121   Prob(JB):                        0.955
# Kurtosis:                       3.153   Cond. No.                     1.82e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.82e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm

# 독립 변수 열 선택
independent_variable_columns = ['Agricultural ＆ marine products', 'Electricity and Gas and Water']

# 데이터프레임에서 필요한 열만 추출
data = ndf[independent_variable_columns]

# 상수 열 추가
X = sm.add_constant(data)

# VIF 계산
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# 결과 출력
print("VIF:")
print(vif_data)
# Out:
# VIF:
#                          Variable         VIF
# 0                           const  152.317590
# 1  Agricultural ＆ marine products    1.393964
# 2   Electricity and Gas and Water    1.393964

# %% [markdown]
# VIF 결과:
#
# 'Agricultural ＆ marine products'의 VIF: 1.39
# 'Electricity and Gas and Water'의 VIF: 1.39
# 상수 (const)의 VIF: 152.32
# 해석:
#
# 'Agricultural ＆ marine products'와 'Electricity and Gas and Water' 변수들의 VIF가 모두 1.39로, 일반적으로는 다중 공선성이 문제가 없을 정도로 낮게 나타났습니다.
# 상수 항(const)의 VIF는 152.32로 높게 나타났으나, 상수 항의 다중 공선성은 큰 문제가 되지 않습니다.
# 결론:
#
# 현재의 결과에서는 선택한 독립 변수들 간에 다중 공선성이 크게 나타나지 않습니다.
# 모델의 다중 공선성 문제가 크게 해결되었다고 판단됩니다.
# 앞으로는 이 변수들을 사용한 모델이 더욱 신뢰성 있게 사용될 수 있을 것입니다. 다만, 다른 변수들이나 모델의 구성 등을 고려하여 계속해서 모델을 평가하고 개선해 나가는 것이 중요합니다.

# %%
import statsmodels.api as sm

# 독립 변수 열 선택
independent_variable_columns = ['Agricultural ＆ marine products', 'Electricity and Gas and Water']

# 데이터프레임에서 필요한 열만 추출
data = ndf[independent_variable_columns + ['Personal services']]

# 독립 변수와 종속 변수를 분리
X = sm.add_constant(data[independent_variable_columns])
y = data['Personal services']

# 다중 회귀 모델 학습
model = sm.OLS(y, X).fit()

# 모델 요약 정보 출력
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Personal services   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.942
# Method:                 Least Squares   F-statistic:                     212.6
# Date:                Tue, 05 Dec 2023   Prob (F-statistic):           5.40e-16
# Time:                        01:09:05   Log-Likelihood:                -46.266
# No. Observations:                  27   AIC:                             98.53
# Df Residuals:                      24   BIC:                             102.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             32.1170      3.382      9.495      0.000      25.136      39.098
# Agricultural ＆ marine products     0.4549      0.036     12.544      0.000       0.380       0.530
# Electricity and Gas and Water      0.2194      0.030      7.195      0.000       0.156       0.282
# ==============================================================================
# Omnibus:                        0.622   Durbin-Watson:                   0.797
# Prob(Omnibus):                  0.733   Jarque-Bera (JB):                0.092
# Skew:                          -0.121   Prob(JB):                        0.955
# Kurtosis:                       3.153   Cond. No.                     1.82e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.82e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x_new = ndf[['Agricultural ＆ marine products','Electricity and Gas and Water']]
y_new =ndf['Personal services']

# %%
x_new_train, x_new_test, y_new_train, y_new_test = train_test_split(x_new,y_new,test_size=0.3,random_state=10)

# %%
print('traindata: ',x_new_train.shape)
print('testdata : ',x_new_test.shape)
# Out:
# traindata:  (18, 2)
# testdata :  (9, 2)

# %%
new_lr = LinearRegression()
new_lr.fit(x_new_train, y_new_train)
# Out:
# LinearRegression()

# %%
r_new_square = new_lr.score(x_new_test,y_new_test)
print(r_new_square)
# Out:
# 0.9325743137617126

# %%
print('x_new 변수의 계수 a :', new_lr.coef_)
print('상수항 b', new_lr.intercept_)
# Out:
# x_new 변수의 계수 a : [0.42189908 0.23915931]
# 상수항 b 33.44595710466197

# %%
y_new_hat = new_lr.predict(x_new_test)
plt.figure(figsize=(10,5))
ax1=sns.kdeplot(y_new_test,label="y_new_test")
ax2= sns.kdeplot(y_new_hat, label="y_new_hat",ax=ax1)
plt.legend()
plt.show() #전체적인 회귀
